# %% [markdown]
# # HR DATA ANALYSIS

# %% [markdown]
# Name : Priyanka Pawar

# %% [raw]
# Objective: Using HR Data, to perform
#            1. EDA, factors affecting attrition,Relationship between job satisfaction and other factors like age, department, job role, etc,
#            2. Correlation between distance from home and attrition,
#            3. Distribution of employees across different departments, job roles, and education fields

# %% [markdown]
# #Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Loading the Dataset

# %%
Data=pd.read_csv("C:/Priyanka/Afame Technologies Data Analyst Internship/HR Data.csv")

# %%
Data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #Checking Dimensions of the dataset

# %%
Data.shape
# Out:
# (1470, 35)

# %% [raw]
# Comment: The Dataset contains 1470 observations with 35 variables

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Removing the Unnecessary Columns from the Dataset

# %%
columns_to_remove = ['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours','DailyRate','HourlyRate','MonthlyRate']
# Dropping the columns
data = Data.drop(columns=columns_to_remove)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
# ...

# %%
data.shape
# Out:
# (1470, 28)

# %% [markdown]
# Comment: Now, The Dataset contains 1470 observations with 28 variables

# %% [markdown]
# # Giving the columns new names

# %%
# Rename columns
data = data.rename(columns={
    'Age': 'Age',
    'Attrition': 'Attrition',
    'BusinessTravel': 'Business_Travel',
    'Department': 'Department',
    'DistanceFromHome': 'Distance_From_Home',
    'Education': 'Education',
    'EducationField': 'Education_Field',
    'EnvironmentSatisfaction': 'Environment_Satisfaction',
    'Gender': 'Gender',
    'JobInvolvement': 'Job_Involvement',
    'JobLevel': 'Job_Level',
    'JobRole': 'Job_Role',
    'JobSatisfaction': 'Job_Satisfaction',
    'MaritalStatus': 'Marital_Status',
    'NumCompaniesWorked': 'Num_Companies_Worked',
    'OverTime': 'Over_Time',
    'MonthlyIncome': 'Monthly_Income',
    'PercentSalaryHike': 'Percent_Salary_Hike',
    'PerformanceRating': 'Performance_Rating',
    'RelationshipSatisfaction': 'Relationship_Satisfaction',
    'StockOptionLevel': 'Stock_Option_Level',
    'TotalWorkingYears': 'Total_Working_Years',
    'TrainingTimesLastYear': 'Training_Times_Last_Year',
    'WorkLifeBalance': 'Work_Life_Balance',
    'YearsAtCompany': 'Years_At_Company',
    'YearsInCurrentRole': 'Years_In_Current_Role',
    'YearsSinceLastPromotion': 'Years_Since_Last_Promotion',
    'YearsWithCurrManager': 'Years_With_Curr_Manager'
})

# %%
data.head()
# Out:
#    Age Attrition    Business_Travel              Department  \
# 0   41       Yes      Travel_Rarely                   Sales
# 1   49        No  Travel_Frequently  Research & Development
# 2   37       Yes      Travel_Rarely  Research & Development
# 3   33        No  Travel_Frequently  Research & Development
# 4   27        No      Travel_Rarely  Research & Development
#
#    Distance_From_Home  Education Education_Field  Environment_Satisfaction  \
# 0                   1          2   Life Sciences                         2
# 1                   8          1   Life Sciences                         3
# 2                   2          2           Other                         4
# 3                   3          4   Life Sciences                         4
# 4                   2          1         Medical                         1
#
#    Gender  Job_Involvement  ...  Performance_Rating Relationship_Satisfaction  \
# ...

# %% [markdown]
# #Checking for Missing Values

# %%
data.isnull().sum()
# Out:
# Age                           0
# Attrition                     0
# Business_Travel               0
# Department                    0
# Distance_From_Home            0
# Education                     0
# Education_Field               0
# Environment_Satisfaction      0
# Gender                        0
# Job_Involvement               0
# Job_Level                     0
# Job_Role                      0
# Job_Satisfaction              0
# Marital_Status                0
# Monthly_Income                0
# Num_Companies_Worked          0
# Over_Time                     0
# Percent_Salary_Hike           0
# Performance_Rating            0
# Relationship_Satisfaction     0
# Stock_Option_Level            0
# Total_Working_Years           0
# Training_Times_Last_Year      0
# Work_Life_Balance             0
# Years_At_Company              0
# Years_In_Current_Role         0
# Years_Since_Last_Promotion    0
# Years_With_Curr_Manager       0
# dtype: int64

# %% [markdown]
# #Checking the columns having NaN values

# %%
# Checking for NaN values in the entire dataset
nan_values = data.isna().sum()
# Print the columns with NaN values and their counts
print("Columns with NaN values:")
print(nan_values[nan_values > 0])
# Out:
# Columns with NaN values:
# Series([], dtype: int64)

# %% [markdown]
# Comment : There are no NaN values in the dataset

# %%
data.shape
# Out:
# (1470, 28)

# %% [markdown]
# #Summary Statistics

# %%
data.describe().T
# Out:
#                              count         mean          std     min     25%  \
# Age                         1470.0    36.923810     9.135373    18.0    30.0
# Distance_From_Home          1470.0     9.192517     8.106864     1.0     2.0
# Education                   1470.0     2.912925     1.024165     1.0     2.0
# Environment_Satisfaction    1470.0     2.721769     1.093082     1.0     2.0
# Job_Involvement             1470.0     2.729932     0.711561     1.0     2.0
# Job_Level                   1470.0     2.063946     1.106940     1.0     1.0
# Job_Satisfaction            1470.0     2.728571     1.102846     1.0     2.0
# Monthly_Income              1470.0  6502.931293  4707.956783  1009.0  2911.0
# Num_Companies_Worked        1470.0     2.693197     2.498009     0.0     1.0
# Percent_Salary_Hike         1470.0    15.209524     3.659938    11.0    12.0
# Performance_Rating          1470.0     3.153741     0.360824     3.0     3.0
# ...

# %% [raw]
# Comment : 1.From Summary Statistics, we see that, the average age is 36.92 years, the average distance from home is 9.19 miles,
#           and the average monthly income is $6502.93.
#          2.The minimum age is 18 years, the minimum distance from home is 1 mile, and the minimum monthly income is $1009.
#          3. The maximum age is 60 years, the maximum distance from home is 29 miles, and the maximum monthly income is $19999.

# %% [markdown]
# # UNIVARITAE ANALYSIS

# %% [markdown]
# # Plotting Histogram of Age

# %%
plt.hist(data['Age'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %% [raw]
# Comment: 1. The histogram indicates that the age distribution is likely right-skewed. This means there are more people on the younger side and
#          fewer people on the older side.
#          2. The peak of the distribution appears somewhere in the mid-to-late 20s or early 40s.

# %% [markdown]
# # Count Plot of Job Role

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Job_Role')
plt.xticks(rotation=45)
plt.xlabel('Job Role')
plt.ylabel('Count')
plt.title('Count of Employees by Job Role')
# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [raw]
# Comment : The dataset contains majority of employees from the sales executive, followed by Research Scientists, Lab technician etc.

# %% [markdown]
# # Pie Chart of Gender Distribution

# %%
plt.figure(figsize=(8, 8))
data['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %% [raw]
# Comment: The dataset contains 60 % Male employees and 40 % Female employees

# %% [markdown]
# # Histogram of Years at Company

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Years_At_Company'], bins=20, color='salmon', edgecolor='black')
plt.xlabel('Years at Company')
plt.ylabel('Frequency')
plt.title('Histogram of Years at Company')
plt.show()

# %% [raw]
# Comment : 1. The distribution appears to be right-skewed, that means, there are more employees with fewer years at the company compared
#           to those who have been there for a longer time.
#           2.The histogram shows a peak around 5-10 years, that means, significant portion of employees have been with the company for a moderate time.

# %% [markdown]
# # Count Plot of Marital Status

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Marital_Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.title('Count of Employees by Marital Status')
plt.show()

# %% [raw]
# Comment : The dataset contains majority of employees that are Married followed by Singles and also few Divorced.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# # Boxplot of Monthly Income by Department

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Department', y='Monthly_Income')
plt.xlabel('Department')
plt.ylabel('Monthly Income')
plt.title('Monthly Income by Department')
plt.show()

# %% [markdown]
# # Scatter Plot of Age vs. Years at Company

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['Age'], data['Years_At_Company'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Years at Company')
plt.title('Age vs. Years at Company')
plt.show()

# %% [raw]
# Comment: 1. The scatter plotshows the relationship between age and years at company.
#          2. There appears to be a positive correlation between age and years at company.
#         This means that, as employees get older, they tend to have more years with the company.
#          3. Also, Some employees stay with the company for many years, while others leave after a shorter period.

# %% [markdown]
# # Bar Plot of Attrition by Gender

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=data, x='Gender', hue='Attrition')

# Add counts above the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Attrition Count by Gender')
plt.legend(title='Attrition')
plt.show()

# %% [raw]
# Comment: From the above graph, we can see that, Male as well as females have left the service,but,  there are more males who left the
#          service than   females.

# %% [markdown]
# # Boxplot of Years at Company by Job Role

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Job_Role', y='Years_At_Company')
plt.xticks(rotation=45)
plt.xlabel('Job Role')
plt.ylabel('Years at Company')
plt.title('Years at Company by Job Role')
plt.show()

# %% [markdown]
# # Bar Plot of Attrition by Education Field

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Education_Field', hue='Attrition')
plt.xlabel('Education Field')
plt.ylabel('Count')
plt.title('Attrition Count by Education Field')
plt.legend(title='Attrition')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Comment: 1.From the above graph we can see that, most of the employees from the life science field has left their service followed by, medical field.
#          2. Also, There are majority of employees from the same departments followed by marketing and technical degree.

# %% [markdown]
# # Insights for  defined Objectives

# %% [markdown]
# # factors affecting attrition

# %%
# Attrition rates
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Attrition', palette='Set1')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.title('Attrition Rates')
plt.show()
# Out:
# C:\Users\Ravindra\AppData\Local\Temp\ipykernel_27996\114681919.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Attrition', palette='Set1')

# %%
# Factors affecting attrition
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Attrition', hue='Department')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.title('Attrition by Department')
plt.legend(title='Department')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Attrition', hue='Job_Role')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.title('Attrition by Job Role')
plt.legend(title='Job Role')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Attrition', hue='Job_Satisfaction')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.title('Attrition by Job_Satisfaction')
plt.legend(title='Job_Satisfaction')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Comment:  1. The Dataset contains more of the employees who does not want to leave the organization.
#           2. But, it seems , the department of research and development employees tends more towards attrition.
#           3. Employees having Job Role, Lab technician, Sales Executive, Research scientits tends towards attrition.
#           4. There seems to be a trend where more employees leave the organization with lower job satisfaction levels.

# %% [markdown]
# # Relationship between job satisfaction and other factors like age, department, job role

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Job_Satisfaction', y='Age')
plt.xlabel('Job Satisfaction')
plt.ylabel('Age')
plt.title('Relationship between Job Satisfaction and Age')
plt.show()

# %% [raw]
# Comment: 1.The box plot shows that job satisfaction tends to increase with age.
#          2. The median job satisfaction score is higher for older workers than for younger workers.
#          3. As we know, the spread of the data is larger for older workers than for younger workers, that means,that there is more variation in
#          job satisfaction among older workers than among younger workers.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Job_Satisfaction', y='Department')
plt.xlabel('Job Satisfaction')
plt.ylabel('Department')
plt.title('Relationship between Job Satisfaction and department')
plt.show()

# %% [raw]
# Comment: We can see that, the employees in every department have the highest median job satisfaction.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Job_Satisfaction', y='Job_Role')
plt.xlabel('Job Satisfaction')
plt.ylabel('Job_Role')
plt.title('Relationship between Job Satisfaction and Job Role')
plt.show()

# %% [raw]
# Comment: We can see that,that above Research Director , all has the highest median job satisfaction, and then Human Resources.

# %% [markdown]
# # Correlation between distance from home and attrition

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Attrition', y='Distance_From_Home')
plt.xlabel('Attrition')
plt.ylabel('Distance From Home')
plt.title('Correlation between Distance From Home and Attrition')
plt.show()

# %% [raw]
# Comment: The data points show a higher attrition rate for employees who live farther away from their workplace  compared to those who live closer.

# %% [markdown]
# # Distribution of employees across different departments, job roles, and education fields

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.title('Distribution of Employees by Department')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Job_Role')
plt.xlabel('Job Role')
plt.ylabel('Count')
plt.title('Distribution of Employees by Job Role')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Education_Field')
plt.xlabel('Job Role')
plt.ylabel('Count')
plt.title('Distribution of Employees by Education_Field')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Comment : The dataset contains,
#         1.majority of employees from the Research And Develpment Department.
#         2. Majority of employees having the job role as,  the sales executive, followed by Research Scientists, Lab technician etc.
#          3. And Majority of employees from the education field of, Life sciences,Medical, Marketing, etc.

# %% [markdown]
# # Impact of Income and Overtime on Attrition

# %%
# Set a low income threshold (e.g., 25th percentile of Monthly_Income)
low_income_threshold = data['Monthly_Income'].quantile(0.25)

# Create a new column for identifying employees who work overtime and have low income
data['Overworked_Underpaid'] = (data['Over_Time'] == 'Yes') & (data['Monthly_Income'] < low_income_threshold)

# Plotting the scatter plot with hue for Attrition and style for Overworked_Underpaid
plt.figure(figsize=(12, 8))
sns.scatterplot(data=data, x='Monthly_Income', y='Years_At_Company', hue='Attrition', style='Overworked_Underpaid', palette='Set1', s=100, alpha=0.6)

# Add regression lines
sns.regplot(data=data[data['Overworked_Underpaid'] == True], x='Monthly_Income', y='Years_At_Company', scatter=False, color='red', label='Overworked & Underpaid')
sns.regplot(data=data[data['Overworked_Underpaid'] == False], x='Monthly_Income', y='Years_At_Company', scatter=False, color='blue', label='Others')

# Add plot labels and title
plt.xlabel('Monthly Income')
plt.ylabel('Years at Company')
plt.title('Impact of Income and Overtime on Attrition')
plt.legend(title='Attrition & Overworked/Underpaid')
plt.grid(True)

# Show the plot
plt.show()

# %% [raw]
# Comment: The graph shows "Impact of Income and Overtime on Attrition".
#         It shows two relationships,
#         1.between income and attrition and
#         2.between overtime and attrition.
#         3. The blue line shows a negative correlation between income and attrition.
#         This means that as income increases, attrition decreases.
#         That is, employees who are paid more are less likely to leave the company.
#         4.The red line shows a positive correlation between overtime and attrition.
#         This means that, as overtime increases, attrition increases as well.
#         That is, employees who work more overtime are more likely to leave the company.
#         5.Also,According to this data, the  Employees who are paid more may feel more valued by their employer and may be more likely to
#          be satisfied with their jobs.
#         And employees who work a lot of overtime may be burnt out and stressed, which could lead them to look for a new job.
