# %% [markdown]
# # SALES DATA ANALYSIS

# %% [markdown]
# Name : Priyanka Pawar

# %% [markdown]
# Objective : Using Sales Data to find patterns, best selling items, total sales, revenue indicators, and analyze sales trends over time.

# %% [markdown]
# #Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Loading the Dataset

# %%
data=pd.read_csv("C:/Priyanka/Afame Technologies Data Analyst Internship/DATA.csv",encoding='iso-8859-1')

# %%
data.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#     Region    Category Sub-Category  \
# 0     East  Technology  Accessories
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #Checking Dimensions of the dataset

# %%
data.shape
# Out:
# (51290, 21)

# %% [raw]
# Comment: The Dataset contains 51290 observations with 21 variables

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Region          51290 non-null  object
#  12  Category        51290 non-null  object
#  13  Sub-Category    51290 non-null  object
#  14  Product Name    51290 non-null  object
#  15  Sales           51290 non-null  float64
#  16  Quantity        51290 non-null  int64
# ...

# %% [markdown]
# #Checking for Missing Values

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %% [raw]
# Comment :There are no missing observations in the dataset

# %% [markdown]
# #Summary statistics

# %%
data.describe().T
# Out:
#                  count          mean           std       min           25%  \
# Row ID         51290.0  25645.500000  14806.291990     1.000  12823.250000
# Sales          51290.0    246.490581    487.565361     0.444     30.758625
# Quantity       51290.0      3.476545      2.278766     1.000      2.000000
# Discount       51290.0      0.142908      0.212280     0.000      0.000000
# Profit         51290.0     28.610982    174.340972 -6599.978      0.000000
# Shipping Cost  51290.0     26.375915     57.296804     0.000      2.610000
#
#                      50%         75%        max
# Row ID         25645.500  38467.7500  51290.000
# Sales             85.053    251.0532  22638.480
# Quantity           3.000      5.0000     14.000
# Discount           0.000      0.2000      0.850
# Profit             9.240     36.8100   8399.976
# Shipping Cost      7.790     24.4500    933.570

# %% [raw]
# Comment: 1. By Summary statistics we can see that,the sales amounts to 246.49 with the discount of 0.14 and profit of 28.61.
#          2. Also, we can see the shipping cost ranges widely that is, from minimum 0 to maximum 933.57.
#          3. The profit shows high variability, that is , with the mean of 28.61 and SD 174.34. We can see some losses as well as the maximum profit is              8399.97.

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# # customer segments

# %%
# Bar plot for 
plt.figure(figsize=(5, 6))
sns.countplot(x='Segment', data=data)
plt.title('Frequency of Segments')
plt.xlabel('Segment')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Pie chart
segment_counts = data['Segment'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%')
plt.title('Segment Distribution')
plt.show()

# %% [raw]
# Comment: The largest segment is of Consumer, followed by Corporate and then Home Office.

# %% [markdown]
# # Category Distribution

# %%
# Bar plot
plt.figure(figsize=(5, 6))
sns.countplot(x='Category', data=data)
plt.title('Frequency of Category')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Pie chart
segment_counts = data['Category'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%')
plt.title('Category Distribution')
plt.show()

# %% [raw]
# Comment: Office supplies make up the majority of the category distribution at 61%.
#          Technology and furniture follow at around 19% each.

# %% [markdown]
# # Sub-Category Distribution

# %%
# Bar plot
plt.figure(figsize=(5, 6))
sns.countplot(x='Sub-Category', data=data)
plt.title('Frequency of Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Comment : Binders are the most popular subcategory, followed by storage,paper and envelopes.

# %% [markdown]
# # Pie Chart for  Country & Region Distribution

# %%
# Pie chart
segment_counts = data['Region'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%')
plt.title('Region Distribution')
plt.show()

# Pie chart
segment_counts = data['Country'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%')
plt.title('Country Distribution')
plt.show()

# %% [raw]
# Comment: In the dataset, The United States has the largest portion of 19.5%. Australia is the second largest, followed by, France, mexico, germany etc.

# %% [markdown]
# # Plotting histograms for Sales, Discount, and Profit.

# %% [markdown]
# # SALES

# %%
#Using Log to better visualize the spread of the data.
plt.figure(figsize=(10, 6))
plt.hist(data['Sales'], bins=30, color='skyblue', edgecolor='black', log=True)
plt.title('Sales Distribution (Log Scale)')
plt.xlabel('Sales')
plt.ylabel('Frequency (log scale)')
plt.show()

# %% [raw]
# Comment: 1. From the above histogram we can see that, the sales is right skewed, the majority of sales are towards the lower, that means, most
#          transactions or sales are done of lower value.
#          2.Also, we can see that, as sales value increases, the transactions decreases.
#          3. The sales ranges from 0 to approximately 20 thousand.
#          4. There are many high value sales which are outliers, this outliers shows the rare sales, which are significant, also which can have a great           impact on the revenue.

# %% [markdown]
# # DISCOUNT

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Discount'], bins=30, color='skyblue', edgecolor='black', log=True)
plt.title('Discount Distribution (Log Scale)')
plt.xlabel('Discount')
plt.ylabel('Frequency (log scale)')
plt.show()

# %% [raw]
# Comment: From the above graph, we can see that most of the discounts falls in the lower range.

# %% [markdown]
# # PROFIT

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Profit'], bins=30, color='skyblue', edgecolor='black', log=True)
plt.title('Profit Distribution (Log Scale)')
plt.xlabel('Profit')
plt.ylabel('Frequency (log scale)')
plt.show()

# %% [raw]
# Comment: We can see that, profits are most frequent between  the range of 2000 .ALso, there is equal losses in the dataset.

# %% [markdown]
# # Plotting Box Plot

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.boxplot(data['Sales'], patch_artist=True)
plt.title('Sales Boxplot')
plt.ylabel('Sales')

plt.subplot(1, 3, 2)
plt.boxplot(data['Discount'], patch_artist=True)
plt.title('Discount Boxplot')
plt.ylabel('Discount')

plt.subplot(1, 3, 3)
plt.boxplot(data['Profit'], patch_artist=True)
plt.title('Profit Boxplot')
plt.ylabel('Profit')

plt.tight_layout()
plt.show()

# %% [raw]
# Comment: 1.From the above box plots, we can see that,  the sales is in the  range of 5000 to 20000.
#          2. Most people received the Discounts on the smaller side.
#          3. Profits are in between, 2000 to 8000, also with most frequent losses as well.

# %% [markdown]
# # Bivariate Analysis

# %%
# Plotting Scatter plots for Sales vs. Profit, Sales vs. Discount, and Profit vs. Discount
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.scatterplot(data=data, x='Sales', y='Profit')
plt.title('Sales vs. Profit')

plt.subplot(1, 3, 2)
sns.scatterplot(data=data, x='Sales', y='Discount')
plt.title('Sales vs. Discount')

plt.subplot(1, 3, 3)
sns.scatterplot(data=data, x='Profit', y='Discount')
plt.title('Profit vs. Discount')

plt.tight_layout()
plt.show()

# %% [raw]
# Comment: 1.There is positive correlation between sales and profit.As sales increases profit also increases.Some sales results in highb profits while
#          others results in losses as well
#          2. There is weak correlation between sales and discount, a negative correlation, as sales increases discounts decreases.Also,  there are
#          outliers, where we can see that, high discounts are given for high sales as well as for low sales.
#          3.The Profit vs.Discount plot is more scatterred, we can see that, high profits are with the lower discount rate.Also, there are low profit
#          and losses.

# %%
# Correlation heatmap(shows the correlation coefficients between different variables.)
plt.figure(figsize=(10, 6))
corr = data[['Sales', 'Discount', 'Profit']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [raw]
# Comment: We know that, -1 indicates negative correlation, 0 indicates no correlation and 1 indicates poitive correlation.
#          1.The Correlation coefficient between sales and discounts is close to 0, that means, no correlation.
#          2.The correlation coefficient between sales and profit is positive, that means, as sales increase profit also increases.
#          3.The correlation coefficient between discounts and profit is close to 0, that means, there is no correlation.
#          This means, sales has a positive impact on profit, but there is no significant correlation between discounts and profits.

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# # Visualizing  best-selling products

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Product Name', data=data, order=data['Product Name'].value_counts().index[:10])
plt.xlabel('Number of Orders')
plt.ylabel('Product Name')
plt.title('Top 10 Best-Selling Products')
plt.show()

# %% [raw]
# Comment : 1. In the above graph , we can see, the top 10 best-selling products. Staples is the best-selling products, with around 200 orders.
#           2. The number of orders for all other products falls below 150.

# %% [markdown]
# #  Analyzing Total sales

# %%
# total_sales is computed
total_sales = data['Sales'].sum()

# Creating a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=['Total Sales'], y=[total_sales], palette='Blues_d')

# Adding title and labels
plt.title('Total Sales')
plt.ylabel('Sales ($)')
plt.xlabel('')

# Annotating the total sales value
plt.text(0, total_sales/2, f'${total_sales:,.2f}', ha='center', color='white', fontsize=14)

plt.show()
# Out:
# C:\Users\Ravindra\AppData\Local\Temp\ipykernel_7864\2073806128.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Total Sales'], y=[total_sales], palette='Blues_d')

# %% [raw]
# Comment : The total sales amount to $12,642,501.91.

# %% [markdown]
# # Total Sales Yearly

# %%
# Assuming your data is in a DataFrame named 'data'
data = pd.DataFrame({
    'Order Date': pd.date_range(start='2011-01-01', end='2014-12-31', freq='D'),
    'Sales': np.random.randint(100, 1000, size=1461)  # Random sales data for example
})

# Ensure 'Order Date' is in datetime format
data['Order Date'] = pd.to_datetime(data['Order Date'])

# Grouping by year
yearly_sales = data.resample('Y', on='Order Date')['Sales'].sum()

# Plotting yearly sales
plt.figure(figsize=(12, 6))
sns.barplot(x=yearly_sales.index.year, y=yearly_sales.values, palette='Blues_d')

# Adding title and labels
plt.title('Yearly Total Sales')
plt.ylabel('Sales ($)')
plt.xlabel('Year')

# Annotating each bar with the sales value
for i in range(len(yearly_sales)):
    plt.text(i, yearly_sales[i], f'${yearly_sales[i]:,.2f}', ha='center', va='bottom', fontsize=10)

plt.show()
# Out:
# C:\Users\Ravindra\AppData\Local\Temp\ipykernel_28192\799662699.py:11: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_sales = data.resample('Y', on='Order Date')['Sales'].sum()
# C:\Users\Ravindra\AppData\Local\Temp\ipykernel_28192\799662699.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=yearly_sales.index.year, y=yearly_sales.values, palette='Blues_d')
# C:\Users\Ravindra\AppData\Local\Temp\ipykernel_28192\799662699.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(i, yearly_sales[i], f'${yearly_sales[i]:,.2f}', ha='center', va='bottom', fontsize=10)

# %% [raw]
# Comment: 1.The graph you provided shows the yearly total sales from 2011 to 2014.
#          2.The y-axis shows sales in dollars, while the x-axis showss the year.
#          3. we can see that, the graph shows a slight increase and decrease in the total sales.
#          4.In 2011, total sales were $203,384,000.Total sales then fluctuated slightly over the next three years.That is, In 2014, total sales were
#         $188,533,000, a decrease of $14,851,000 from 2011.

# %% [markdown]
# # Analyzing Patterns and Sales trend over time

# %%
# Converting date columns to datetime
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%m/%d/%Y')
data['Ship Date'] = pd.to_datetime(data['Ship Date'], format='%m/%d/%Y')

# Extract year and month for trend analysis
data['Order Year'] = data['Order Date'].dt.year
data['Order Month'] = data['Order Date'].dt.month

# Calculating total sales and profit by year
annual_sales = data.groupby('Order Year')['Sales'].sum().reset_index()
annual_profit = data.groupby('Order Year')['Profit'].sum().reset_index()

# Plotting sales and profit over time
plt.figure(figsize=(14, 7))

# %%
# Sales over time
plt.subplot(1, 2, 1)
sns.lineplot(data=annual_sales, x='Order Year', y='Sales', marker='o')
plt.title('Annual Sales')
plt.xlabel('Year')
plt.ylabel('Total Sales')

# Profit over time
plt.subplot(1, 2, 2)
sns.lineplot(data=annual_profit, x='Order Year', y='Profit', marker='o', color='orange')
plt.title('Annual Profit')
plt.xlabel('Year')
plt.ylabel('Total Profit')

plt.tight_layout()
plt.show()

# %% [raw]
# Comment :1.The graph shows the annual sales and annual profit from 2011 to 2014.
#          2. For Annual Sales: Sales appear to fluctuate slightly over the four years.
#          In 2011, sales were $2.25 million. Sales then slightly increased in  2012 to $2.60 million and
#          then increased slightly in 2013 to $2.40 million. In 2014, sales again increased to $4.25 million.
#          3.For Annual Profit: Profits seem to generally increase over the four years.
#         In 2011, profit was $250,000. Profit then increased each year to $300,000 in 2012, $400,000 in 2013, and $500,000 in 2014.

# %%
# Monthly Sales trend
monthly_sales = data.groupby(['Order Year', 'Order Month'])['Sales'].sum().reset_index()
monthly_sales_pivot = monthly_sales.pivot(index='Order Month', columns='Order Year', values='Sales')

plt.figure(figsize=(14, 7))
sns.heatmap(monthly_sales_pivot, cmap='YlGnBu', annot=True, fmt=".1f")
plt.title('Monthly Sales Trend')
plt.xlabel('Year')
plt.ylabel('Month')
plt.show()

# %% [raw]
# Comment: 1.The graph shows the monthly sales trends from 2011 to 2014.
#          2.The Overall Sales Trend shhows a seasonal trend in sales, with sales peaking in the fourth quarter that is in the month of October,
#          November, December and then dropping in the first quarter.
#          3. The Yearly Sales appears to increase year-over-year.
#          4. we can see some outliers in the data. For example, in November 2011, sales appear to be much lower than in November of other years.

# %%
# Category-wise Sales Analysis
category_sales = data.groupby('Category')['Sales'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(data=category_sales, x='Category', y='Sales')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %% [raw]
# Comment: 1.The graph would show the total sales contributed by each category.
#          2. we can see that the category of Technology are the biggest contributors to total sales and the category Office supplies contributes less.

# %%
# Region-wise Sales Analysis
region_sales = data.groupby('Region')['Sales'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(data=region_sales, x='Region', y='Sales')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [raw]
# Comment: 1.The graph shows the total sales by region
#          2.Sales are highest in the Central region, at around $2.5 million, followed by South, North, Southeast and Africa.
#          3.The Caribbean and Canada have the lowest sales, at around $0.2 million.

# %%
# Country-wise Sales Analysis
# Sorting the country_sales DataFrame by sales value
country_sales_sorted = country_sales.sort_values(by='Sales', ascending=False)

# Selecting the top 10 countries
top_10_countries = country_sales_sorted.head(10)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_countries, x='Country', y='Sales')
plt.title('Top 10 Countries by Total Sales')
plt.xlabel('Country')
plt.ylabel('Total Sales')
# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [raw]
# Comment:  1.The graph shows the top 10 countries by total sales
#          2.The United States has the highest total sales ,around 2 million.
#          3.Sales then drops significantly for the other countries like Australia, it is the second-highest selling country , followed by France, China,
#          Germany, Mexico, India, United Kingdom, Indonesia, and Brazil.
